# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
price=[3000,8000,2000,4000,10000,210000]
year=[2015,2016,2017,2022,2024,2026]

plt.plot(year,price)
plt.grid()

# %%
ipl=pd.read_csv("/home/developer/Downloads/sharma-kohli.csv")

# %%
ipl
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(ipl["index"],ipl["V Kohli"],label="rohit")
plt.plot(ipl["index"],ipl["RG Sharma"],linestyle="dotted",marker="o",label="virat")
plt.title("Virat kohli and rohit sharma compresion")
plt.xlabel("season")
plt.ylabel("runs")
plt.legend() # using for label
plt.grid()  # using for readality

# %%
x=np.linspace(-10,10 ,50)
x
# Out:
# array([-10.        ,  -9.59183673,  -9.18367347,  -8.7755102 ,
#         -8.36734694,  -7.95918367,  -7.55102041,  -7.14285714,
#         -6.73469388,  -6.32653061,  -5.91836735,  -5.51020408,
#         -5.10204082,  -4.69387755,  -4.28571429,  -3.87755102,
#         -3.46938776,  -3.06122449,  -2.65306122,  -2.24489796,
#         -1.83673469,  -1.42857143,  -1.02040816,  -0.6122449 ,
#         -0.20408163,   0.20408163,   0.6122449 ,   1.02040816,
#          1.42857143,   1.83673469,   2.24489796,   2.65306122,
#          3.06122449,   3.46938776,   3.87755102,   4.28571429,
#          4.69387755,   5.10204082,   5.51020408,   5.91836735,
#          6.32653061,   6.73469388,   7.14285714,   7.55102041,
#          7.95918367,   8.36734694,   8.7755102 ,   9.18367347,
#          9.59183673,  10.        ])

# %%
y=10*x+3 +np.random.randint(0,300,50)

# %%
y
# Out:
# array([171.        , 198.08163265,  -1.83673469,  79.24489796,
#        -33.67346939,  30.40816327, 199.48979592,  12.57142857,
#         -8.34693878, -58.26530612, 217.81632653, -31.10204082,
#         62.97959184,  76.06122449, 111.14285714, 226.2244898 ,
#        209.30612245, 101.3877551 , 239.46938776,  80.55102041,
#        230.63265306, 216.71428571,  19.79591837, 194.87755102,
#        118.95918367,  64.04081633, 286.12244898, 206.20408163,
#        251.28571429,  25.36734694, 237.44897959, 171.53061224,
#        145.6122449 ,  37.69387755, 185.7755102 , 118.85714286,
#        120.93877551, 275.02040816, 114.10204082, 146.18367347,
#        120.26530612, 198.34693878, 133.42857143,  78.51020408,
#        323.59183673, 367.67346939, 336.75510204, 228.83673469,
#        379.91836735, 282.        ])

# %%
plt.scatter(x,y)

# %%
ipl2=pd.read_csv("/home/developer/Downloads/batter.csv")

# %%
ipl2
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
df=ipl2.head(50)
df
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# ...

# %%
plt.scatter(df["avg"],df["strike_rate"])
plt.title("top 50 score")
plt.xlabel("average")
plt.ylabel("strike_rate")
# Out:
# Text(0, 0.5, 'strike_rate')
