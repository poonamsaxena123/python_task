# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap

# %%
data=pd.read_csv("Sales_April_2019.csv")

# %%
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
# copy of data
d2=data.copy()

# %%
# info of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18383 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18324 non-null  object
#  1   Product           18324 non-null  object
#  2   Quantity Ordered  18324 non-null  object
#  3   Price Each        18324 non-null  object
#  4   Order Date        18324 non-null  object
#  5   Purchase Address  18324 non-null  object
# dtypes: object(6)
# memory usage: 861.8+ KB

# %%
# top 5 rows
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
# all columns
data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
# last 5 rows
data.tail()
# Out:
#       Order ID                   Product Quantity Ordered Price Each  \
# 18378   194090              Google Phone                1        600
# 18379   194091     AA Batteries (4-pack)                1       3.84
# 18380   194092    AAA Batteries (4-pack)                2       2.99
# 18381   194093     AA Batteries (4-pack)                1       3.84
# 18382   194094  Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# 18378  04/08/19 17:11   177 Jackson St, Los Angeles, CA 90001
# 18379  04/15/19 16:02         311 Forest St, Austin, TX 73301
# 18380  04/28/19 14:36  347 Sunset St, San Francisco, CA 94016
# 18381  04/14/19 15:09         835 Lake St, Portland, OR 97035
# 18382  04/18/19 11:08          354 North St, Boston, MA 02215

# %%
# data type of each column
print(data.dtypes)
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
# shape of data
print("shape of data ",data.shape)
print("numer of rows ",data.shape[0])
print("numer of columns ",data.shape[1])
# Out:
# shape of data  (18383, 6)
# numer of rows  18383
# numer of columns  6

# %%
# statical info
data.describe()
# Out:
#         Order ID                   Product Quantity Ordered Price Each  \
# count      18324                     18324            18324      18324
# unique     17538                        20                8         19
# top     Order ID  Lightning Charging Cable                1      14.95
# freq          35                      2201            16558       2201
#
#         Order Date  Purchase Address
# count        18324             18324
# unique       13584             17120
# top     Order Date  Purchase Address
# freq            35                35

# %%
# find missing values
data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# 'Order Date'        1
# dtype: int64

# %%
sns.heatmap(data.isna(), cbar=False, cmap=ListedColormap(['red', 'yellow']))
plt.title('Missing Values Heatmap')
plt.show()

# %%
data=data.dropna(how="all")
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# 'Order Date'        1
# dtype: int64

# %%
data.shape
# Out:
# (18324, 6)

# %%
data=data.dropna()
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data.duplicated().sum()
# Out:
# 56

# %%
data=data.drop_duplicates()
data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
data['Order ID'] = pd.to_numeric(data['Order ID'])
# Out:
# /tmp/ipykernel_4539/3584844203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Order ID'] = pd.to_numeric(data['Order ID'])

# %%
data.dtypes
# Out:
# Order ID             int64
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
data["Order ID"].isnull().sum()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18267 entries, 0 to 18382
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          18267 non-null  int64
#  1   Product           18267 non-null  object
#  2   Quantity Ordered  18267 non-null  object
#  3   Price Each        18267 non-null  object
#  4   Order Date        18267 non-null  object
#  5   Purchase Address  18267 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 999.0+ KB

# %%
data['Order ID'] = data['Order ID'].astype(int)
# Out:
# /tmp/ipykernel_4539/2576321514.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Order ID'] = data['Order ID'].astype(int)

# %%
data.dtypes
# Out:
# Order ID             int64
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
sns.boxplot(x=data['Quantity Ordered'])
plt.title('Boxplot of Quantity Ordered')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data)
plt.title('Boxplot of Numerical Columns')
plt.show()

# %%
# Extract yesr from dataset
# data["Order Date"]= pd.to_datetime(data["Order Date"])
data["'Order Date'"]=pd.to_datetime(data['Order Date'], errors='coerce')
# Out:
# /tmp/ipykernel_4539/629710424.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["'Order Date'"]=pd.to_datetime(data['Order Date'], errors='coerce')
# /tmp/ipykernel_4539/629710424.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["'Order Date'"]=pd.to_datetime(data['Order Date'], errors='coerce')

# %%
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address  \
# ...

# %%
data.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered            object
# Price Each                  object
# Order Date                  object
# Purchase Address            object
# 'Order Date'        datetime64[ns]
# dtype: object

# %%
# Filter rows for a specific product
filtered_df = data[data['Product'] == 'Google Phone']

# Select specific columns
subset_df = data[['Order ID', 'Product', 'Quantity Ordered']]

# Plot filtered data (example for filtered product)
plt.figure(figsize=(10, 6))
sns.histplot(filtered_df['Quantity Ordered'], bins=.1)
plt.title('Quantity Ordered Distribution for Google Phone')
plt.xlabel('Quantity Ordered')
plt.ylabel('Frequency')
plt.show()

# %%
data.to_csv("cleaning_data",index=True)

# %%
data2=pd.read_csv("/home/developer/Desktop/daily_task/python_task/pandass/cleaning_data")
data2
# Out:
#        Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0               0   176558        USB-C Charging Cable                2
# 1               2   176559  Bose SoundSport Headphones                1
# 2               3   176560                Google Phone                1
# 3               4   176560            Wired Headphones                1
# 4               5   176561            Wired Headphones                1
# ...           ...      ...                         ...              ...
# 18263       18378   194090                Google Phone                1
# 18264       18379   194091       AA Batteries (4-pack)                1
# 18265       18380   194092      AAA Batteries (4-pack)                2
# 18266       18381   194093       AA Batteries (4-pack)                1
# 18267       18382   194094    Lightning Charging Cable                1
#
#       Price Each      Order Date                        Purchase Address  \
# ...

# %%
"04/19/19 08:46".split('/')[0]
# Out:
# '04'
