# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df=pd.read_csv("/home/developer/Downloads/AMZN.csv")

# %%
data=df.copy()

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume
# 0     1443120000
# ...

# %%
data.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6516 entries, 0 to 6515
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6516 non-null   object
#  1   Open       6516 non-null   float64
#  2   High       6516 non-null   float64
#  3   Low        6516 non-null   float64
#  4   Close      6516 non-null   float64
#  5   Adj Close  6516 non-null   float64
#  6   Volume     6516 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 356.5+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# to find outliyears

sns.boxplot(df)
plt.show()

# %%
# to find outlier of open col 
q1=df["Open"].quantile(0.25)
q2=df["Open"].quantile(0.75)

# %%
iqr=q2-q1

# %%
iqr
# Out:
# 36.45249975

# %%
up=q2+1.5*iqr
up
# Out:
# 93.13012437500001

# %%
lo=q1-1.5*iqr
lo
# Out:
# -52.679874625000004

# %%
# find outliers

out=df[(df["Open"]<=lo) | (df["Open"]>=up)]

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume
# 0     1443120000
# ...

# %%
# remove ouliyers
df=df[(df["Open"]>=lo) & (df["Open"]<=up)]

# %%
sns.boxplot(df["Open"])
plt.show()

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     1997-05-15   0.121875   0.125000   0.096354   0.097917   0.097917
# 1     1997-05-16   0.098438   0.098958   0.085417   0.086458   0.086458
# 2     1997-05-19   0.088021   0.088542   0.081250   0.085417   0.085417
# 3     1997-05-20   0.086458   0.087500   0.081771   0.081771   0.081771
# 4     1997-05-21   0.081771   0.082292   0.068750   0.071354   0.071354
# ...          ...        ...        ...        ...        ...        ...
# 6466  2023-01-25  92.559998  97.239998  91.519997  97.180000  97.180000
# 6491  2023-03-02  91.410004  92.230003  90.389999  92.129997  92.129997
# 6492  2023-03-03  92.739998  94.940002  92.660004  94.900002  94.900002
# 6497  2023-03-10  92.669998  93.570000  90.250000  90.730003  90.730003
# 6498  2023-03-13  89.970001  94.019997  88.120003  92.430000  92.430000
#
#           Volume
# 0     1443120000
# 1      294000000
# 2      122136000
# 3      109344000
# ...

# %%
q1=df["Volume"].quantile(0.25)
q2=df["Volume"].quantile(0.75) 
iqr=q2-q1
up=q2+1.5*iqr
up
lo=q1-1.5*iqr
lo
# Out:
# -75094175.0

# %%
# to find outliers in volum col
out=df[(df["Volume"]<=lo) | (df["Volume"]>=up)]
out
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     1997-05-15   0.121875   0.125000   0.096354   0.097917   0.097917
# 4     1997-05-21   0.081771   0.082292   0.068750   0.071354   0.071354
# 89    1997-09-22   0.200000   0.233854   0.197396   0.225000   0.225000
# 198   1998-02-27   0.301042   0.331771   0.299219   0.320833   0.320833
# 204   1998-03-09   0.320313   0.357292   0.319792   0.347917   0.347917
# ...          ...        ...        ...        ...        ...        ...
# 4390  2014-10-24  14.220000  14.690500  14.200000  14.353000  14.353000
# 4456  2015-01-30  17.316000  17.975000  17.037001  17.726500  17.726500
# 4514  2015-04-24  21.950001  22.632500  21.950001  22.254999  22.254999
# 4577  2015-07-24  28.949499  29.028500  26.467501  26.471001  26.471001
# 5148  2017-10-27  52.907001  55.278999  52.527500  55.047501  55.047501
#
#           Volume
# 0     1443120000
# 4      377064000
# 89     338760000
# 198    494136000
# ...

# %%
sns.boxplot(df["Volume"])
plt.show()

# %%
# remove outliers of column volume
df=df[(df["Volume"]>=lo) & (df["Volume"]<=up)]
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1     1997-05-16   0.098438   0.098958   0.085417   0.086458   0.086458
# 2     1997-05-19   0.088021   0.088542   0.081250   0.085417   0.085417
# 3     1997-05-20   0.086458   0.087500   0.081771   0.081771   0.081771
# 5     1997-05-22   0.071875   0.072396   0.065625   0.069792   0.069792
# 6     1997-05-23   0.070313   0.076042   0.066667   0.075000   0.075000
# ...          ...        ...        ...        ...        ...        ...
# 6466  2023-01-25  92.559998  97.239998  91.519997  97.180000  97.180000
# 6491  2023-03-02  91.410004  92.230003  90.389999  92.129997  92.129997
# 6492  2023-03-03  92.739998  94.940002  92.660004  94.900002  94.900002
# 6497  2023-03-10  92.669998  93.570000  90.250000  90.730003  90.730003
# 6498  2023-03-13  89.970001  94.019997  88.120003  92.430000  92.430000
#
#          Volume
# 1     294000000
# 2     122136000
# 3     109344000
# 5     235536000
# ...

# %%
# find outlier of col Low
q1=df["Low"].quantile(0.25)
q2=df["Low"].quantile(0.75) 
iqr=q2-q1
up=q2+1.5*iqr
up
lo=q1-1.5*iqr
lo
# Out:
# -20.53275075

# %%
# to find outliers in Low col
out=df[(df["Low"]<=lo) | (df["Low"]>=up)]
out
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 4871  2016-09-22  39.713501  40.294498  39.713501  40.235001  40.235001
# 4872  2016-09-23  40.156502  40.387501  40.105999  40.287498  40.287498
# 4873  2016-09-26  40.090000  40.296501  39.857498  39.958000  39.958000
# 4874  2016-09-27  40.092499  40.832001  40.055500  40.805500  40.805500
# 4875  2016-09-28  40.900002  41.507000  40.851501  41.436001  41.436001
# ...          ...        ...        ...        ...        ...        ...
# 6466  2023-01-25  92.559998  97.239998  91.519997  97.180000  97.180000
# 6491  2023-03-02  91.410004  92.230003  90.389999  92.129997  92.129997
# 6492  2023-03-03  92.739998  94.940002  92.660004  94.900002  94.900002
# 6497  2023-03-10  92.669998  93.570000  90.250000  90.730003  90.730003
# 6498  2023-03-13  89.970001  94.019997  88.120003  92.430000  92.430000
#
#         Volume
# 4871  81578000
# 4872  47070000
# 4873  53028000
# 4874  76392000
# 4875  88442000
# ...

# %%
df=df[(df["Low"]>=lo) & (df["Low"]<=up)]
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1     1997-05-16   0.098438   0.098958   0.085417   0.086458   0.086458
# 2     1997-05-19   0.088021   0.088542   0.081250   0.085417   0.085417
# 3     1997-05-20   0.086458   0.087500   0.081771   0.081771   0.081771
# 5     1997-05-22   0.071875   0.072396   0.065625   0.069792   0.069792
# 6     1997-05-23   0.070313   0.076042   0.066667   0.075000   0.075000
# ...          ...        ...        ...        ...        ...        ...
# 4940  2016-12-30  38.323502  38.369999  37.414001  37.493500  37.493500
# 4941  2017-01-03  37.896000  37.938000  37.384998  37.683498  37.683498
# 4942  2017-01-04  37.919498  37.984001  37.709999  37.859001  37.859001
# 4943  2017-01-05  38.077499  39.119999  38.013000  39.022499  39.022499
# 4944  2017-01-06  39.118000  39.972000  38.924000  39.799500  39.799500
#
#          Volume
# 1     294000000
# 2     122136000
# 3     109344000
# 5     235536000
# ...

# %%
sns.boxplot(df["High"])
plt.show()

# %%
# find outlier of col high
q1=df["High"].quantile(0.25)
q2=df["High"].quantile(0.75) 
iqr=q2-q1
up=q2+1.5*iqr
up
lo=q1-1.5*iqr
lo
# Out:
# -12.521156249999999

# %%
 #to find outliers in High col
out=df[(df["High"]<=lo) | (df["High"]>=up)]
out
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 4578  2015-07-27  26.387501  27.247499  26.330000  26.570499  26.570499
# 4579  2015-07-28  26.799999  26.819500  26.156000  26.301500  26.301500
# 4580  2015-07-29  26.546000  26.648500  26.250999  26.450001  26.450001
# 4581  2015-07-30  26.382500  26.959999  26.214500  26.837999  26.837999
# 4582  2015-07-31  26.954500  27.142000  26.726000  26.807501  26.807501
# ...          ...        ...        ...        ...        ...        ...
# 4940  2016-12-30  38.323502  38.369999  37.414001  37.493500  37.493500
# 4941  2017-01-03  37.896000  37.938000  37.384998  37.683498  37.683498
# 4942  2017-01-04  37.919498  37.984001  37.709999  37.859001  37.859001
# 4943  2017-01-05  38.077499  39.119999  38.013000  39.022499  39.022499
# 4944  2017-01-06  39.118000  39.972000  38.924000  39.799500  39.799500
#
#          Volume
# 4578  149820000
# 4579  105462000
# 4580   75052000
# 4581   74862000
# ...

# %%
df=df[(df["Low"]>=lo) & (df["Low"]<=up)]
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1     1997-05-16   0.098438   0.098958   0.085417   0.086458   0.086458
# 2     1997-05-19   0.088021   0.088542   0.081250   0.085417   0.085417
# 3     1997-05-20   0.086458   0.087500   0.081771   0.081771   0.081771
# 5     1997-05-22   0.071875   0.072396   0.065625   0.069792   0.069792
# 6     1997-05-23   0.070313   0.076042   0.066667   0.075000   0.075000
# ...          ...        ...        ...        ...        ...        ...
# 4714  2016-02-09  23.900499  24.919001  23.700001  24.103500  24.103500
# 4715  2016-02-10  24.587999  25.233000  24.299999  24.524000  24.524000
# 4716  2016-02-11  24.558500  25.465000  24.200001  25.191000  25.191000
# 4717  2016-02-12  25.535000  25.837500  25.074499  25.354000  25.354000
# 4718  2016-02-16  25.974001  26.222500  25.583000  26.055000  26.055000
#
#          Volume
# 1     294000000
# 2     122136000
# 3     109344000
# 5     235536000
# ...

# %%
sns.boxplot(df["High"])
plt.show()

# %%
# calculate the mean, median, and standard deviation of the Close prices.
# mean()
df["Close"].mean()
# Out:
# 5.751041625477099

# %%
# median()
df["Close"].median()
# Out:
# 3.16

# %%
# standard deviation
df["Close"].std()
# Out:
# 5.837690141787304

# %%
#Find the highest and lowest Volume traded in the dataset.

df["Volume"].min()
# Out:
# 9744000

# %%
# max values of Volume
df["Volume"].max()
# Out:
# 322352000

# %%
# To convert in date time format 
df["Date"]=pd.to_datetime(df["Date"])

# %%
# Determine the daily returns and plot the histogram of daily returns. 
df["Day"]=df["Date"].dt.day
df
df["year"]=df["Date"].dt.year
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1    1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2    1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3    1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4    1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...         ...         ...         ...         ...         ...         ...
# 6511 2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512 2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513 2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514 2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515 2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume  Day  year
# ...

# %%
#Calculate and plot the moving average of the Close price over a 30-day window.

dff=df["Close"].rolling(window=30).mean()
dff
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 6511    96.010666
# 6512    96.182000
# 6513    96.355667
# 6514    96.668000
# 6515    96.845000
# Name: Close, Length: 6516, dtype: float64

# %%
# Plot the Close prices and the 30-day moving average
plt.figure(figsize=(14, 7))
sns.lineplot(x=df['Date'], y=df['Close'],label='Close Price', color='blue')
plt.plot(df['Date'], dff, label='30-Day Moving Average', color='orange')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Close Price and 30-Day Moving Average')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the Close price over time.  
sns.lineplot(x=df["Date"],y=df["Close"],color="orange")
plt.grid(True)

plt.show()

# %%
# Plot the Volume of trades over time.
plt.figure(figsize=(10,6))
sns.lineplot(x="Date",y="Volume",data=df,color="green")
plt.grid(True)
plt.show()

# %%
# Compute the correlation matrix for the columns Open, High, Low, Close, Adj Close, and Volume. 
new_matrix=df[["Open","High","Low","Close","Adj Close","Volume"]].corr()

# %%
new_matrix
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999913  0.999894  0.999789   0.999789 -0.264083
# High       0.999913  1.000000  0.999868  0.999899   0.999899 -0.262940
# Low        0.999894  0.999868  1.000000  0.999903   0.999903 -0.265308
# Close      0.999789  0.999899  0.999903  1.000000   1.000000 -0.264120
# Adj Close  0.999789  0.999899  0.999903  1.000000   1.000000 -0.264120
# Volume    -0.264083 -0.262940 -0.265308 -0.264120  -0.264120  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(new_matrix,annot=True)
plt.show()
