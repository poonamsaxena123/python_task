# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
engine =sqllachemy.create_engine('mysql+pymysql://root:poonamsaxena1508@localhost:3306/collage')
# df = pd.read_sql_table("dept",engine)

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

# %%
# 1 scatter plot
sns.scatterplot(x=x,y=y)
plt.title("scatter plot of seaorn")
plt.show()

# %%
sns.set_theme()

# %%
import numpy as np
import seaborn as sns

sns.set(style="darkgrid")

# Generate a random univariate dataset
rs = np.random.RandomState(10)
d = rs.normal(size=100)

# Plot a simple histogram and kde
sns.histplot(d, kde=True, color="m")
# Out:
# <Axes: ylabel='Count'>

# %%
data = {
    'Make': ['Toyota', 'Honda', 'Ford', 'Chevrolet', 'Nissan', 'BMW', 'Mercedes', 'Volkswagen', 'Audi', 'Hyundai'],
    'Model': ['Corolla', 'Civic', 'Focus', 'Malibu', 'Sentra', '3 Series', 'C-Class', 'Golf', 'A4', 'Elantra'],
    'Year': [2010, 2012, 2014, 2015, 2011, 2016, 2017, 2013, 2018, 2019],
    'Mileage': [120000, 90000, 110000, 85000, 95000, 60000, 70000, 80000, 50000, 40000],
    'Price': [7000, 8000, 6000, 9500, 7200, 15000, 20000, 12000, 18000, 13000],
    'MPG': [30, 28, 27, 25, 29, 35, 33, 32, 34, 31]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#          Make     Model  Year  Mileage  Price  MPG
# 0      Toyota   Corolla  2010   120000   7000   30
# 1       Honda     Civic  2012    90000   8000   28
# 2        Ford     Focus  2014   110000   6000   27
# 3   Chevrolet    Malibu  2015    85000   9500   25
# 4      Nissan    Sentra  2011    95000   7200   29
# 5         BMW  3 Series  2016    60000  15000   35
# 6    Mercedes   C-Class  2017    70000  20000   33
# 7  Volkswagen      Golf  2013    80000  12000   32
# 8        Audi        A4  2018    50000  18000   34
# 9     Hyundai   Elantra  2019    40000  13000   31

# %%
sns.histplot(df["Year"],color='m',kde=True)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
sns.lineplot(df[["Year","Price"]])
# Out:
# <Axes: >

# %%
sns.set(style="ticks")
x1 =['sun', 'mon', 'fri', 'sat', 'tue', 'wed', 'thu'] 
y1 =[5, 6.7, 4, 6, 2, 4.9, 1.8]

# %%
plt.plot(x,y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]
x1=pd.DataFrame({"x1":x,"y":y})
sns.lineplot(x='x1',y='y',data=x1)
plt.show()

# %%
dff=sns.load_dataset("penguins")

# %%
dff
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data=dff,hue="sex",style="sex",palette='Accent',markers=['o','>'],legend=False)
plt.grid()
plt.show()

# %%
# histogram plot
sns.histplot(dff["bill_length_mm"],bins=20,kde=True,color='red')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
# ar plot in seaoren
sns.barplot(x='bill_length_mm',y='bill_depth_mm',data=dff,hue="sex",orient="h")
plt.show()

# %%
# ar plot in seaoren
sns.set(style="dark")
sns.barplot(x='island',y='bill_length_mm',data=dff,hue="sex",saturation=0.5, palette ='plasma')
plt.show()

# %%
arr=np.array([2,3,4,5,6,78,1,2,233,4,54,55,100,66,444,22,22,2,1,90,56,322,233,55,200])
sns.histplot(x=arr)
# Out:
# <Axes: ylabel='Count'>

# %%
# scatter plot
# sns.set(style=)
sns.scatterplot(x="species",y="bill_depth_mm",data=dff.head(20),hue="sex",style="sex",size="sex",sizes=[100,40],palette="dark",alpha=0.5)
plt.show()

# %%
import seaborn
 
 
seaborn.set(style='whitegrid')
fmri = seaborn.load_dataset("fmri")
 
seaborn.scatterplot(x="timepoint",
                    y="signal",
                    data=fmri,palette='pastel')
# Out:
# /tmp/ipykernel_5943/1077379560.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   seaborn.scatterplot(x="timepoint",
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
# 5 heatmap
arr=np.linspace(1,10,20).reshape(4,5)
arr
# Out:
# array([[ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684],
#        [ 3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789],
#        [ 5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895],
#        [ 8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]])

# %%
sns.heatmap(arr,vmin=0,vmax=12,cmap="PuOr",annot=True,linewidth=10,linecolor="yellow")

plt.show()

# %%
arr1=sns.load_dataset("anagrams")
arr1
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
x=arr1.drop(columns=["attnr"],axis=1)
x.head(10)
# Out:
#    subidr  num1  num2  num3
# 0       1     2   4.0     7
# 1       2     3   4.0     5
# 2       3     3   5.0     6
# 3       4     5   7.0     5
# 4       5     4   5.0     8
# 5       6     5   5.0     6
# 6       7     5   4.5     6
# 7       8     5   7.0     8
# 8       9     2   3.0     7
# 9      10     6   5.0     6

# %%
sns.heatmap(x.head(10),vmin=1,vmax=12,cmap="winter_r")
# Out:
# <Axes: >

# %%
# 6 count plot
plt.grid()
sns.countplot(x="sex",data=dff,color="yellow",saturation=0.8,palette="Set2",hue="sex")
plt.show()

# %%
dff["island"].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
# violin plot 
f = seaborn.load_dataset("fmri") 

f
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.violinplot(x="timepoint",y="signal",data=f.head(100),saturation=0.9,hue='region')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
# 7 pair plot
t=sns.load_dataset("tips")
t['total_bill'].max()
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 7 pair plot
plt.scatter(t["total_bill"],t["tip"])
plt.show()

# %%
# 7 pair plot
sns.pairplot(t,hue='sex',palette='dark',kind="reg")
plt.show()

# %%
# 8 strip plot 
sns.stripplot(x="day",y="total_bill",data=t,hue='sex',palette='rocket_r')
plt.show()

# %%
# 8 strip plot 
sns.stripplot(x=t["total_bill"],data=t)
plt.show()

# %%
# 9 ox plot
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=t,hue='sex',palette='plasma')
plt.show()

# %%
# 9 ox plot
sns.set(style="whitegrid")
sns.boxplot(data=t,palette='plasma',orient='h')
plt.show()

# %%
# if we want to single ox plot
sns.boxplot(y=t["total_bill"],palette='plasma',orient='h')
plt.show()
# Out:
# /home/developer/.local/lib/python3.8/site-packages/seaborn/_base.py:1601: UserWarning: Horizontal orientation ignored with only `y` specified.
#   warnings.warn(single_var_warning.format("Horizontal", "y"))
# /tmp/ipykernel_5943/991203476.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=t["total_bill"],palette='plasma',orient='h')

# %%
# factore plot and cat plot

sns.catplot(x="size",y="tip",data=t,hue="sex")
plt.show()

# %%
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# factGrid
fg=sns.FacetGrid(t,col="sex",hue="day")
fg.map(plt.bar,"total_bill","tip").add_legend()
plt.show()

# %%
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# find outliers
Q1= df[t].quantile(0.25)
Q3=df[t].quantile(0.75)

IQR= Q3-Q1
IQR
lo=Q1-1.5* IQR
upp=Q3-1.5*IQR
outliyer= df[]
